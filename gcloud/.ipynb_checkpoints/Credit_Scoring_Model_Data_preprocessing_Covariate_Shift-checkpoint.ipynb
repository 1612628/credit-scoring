# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.chdir("/content/drive/My Drive/Thesis/Kalapa")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# numpy and pandas for data manipulation
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
# %matplotlib inline

# Garbage collector
import gc
gc.enable()

# !pip3 install unidecode
# !pip3 install ipython-autotime
# %load_ext autotime
# Out:
# ...
#      |████████████████████████████████| 245kB 8.4MB/s
# ...
#   Created wheel for ipython-autotime: filename=ipython_autotime-0.1-cp36-none-any.whl size=1832 sha256=12c01054575939aa9c3af50345fcd98603d8d91ba4e5455816293cf4a9145d3e
#   Stored in directory: /root/.cache/pip/wheels/d2/df/81/2db1e54bc91002cec40334629bc39cfa86dff540b304ebcd6e
# Successfully built ipython-autotime
# ...

# %%
train_raw = pd.read_csv('./input/train_input_preprocessed.csv')
test_raw = pd.read_csv('./input/test_input_preprocessed.csv')
# Out:
# time: 5.42 s

# %%
kfold = []
for i in range(0,5):
  X_train = pd.read_csv("./cv_input/X_train_preprocessed_{}.csv".format(i + 1))
  y_train = pd.read_csv("./cv_input/y_train_{}.csv".format(i + 1))
  X_dev = pd.read_csv("./cv_input/X_dev_preprocessed_{}.csv".format(i + 1))
  y_dev = pd.read_csv("./cv_input/y_dev_{}.csv".format(i + 1))
  kfold.append({
      "X_train": X_train,
      "y_train": y_train['label'],
      "X_dev": X_dev,
      "y_dev": y_dev['label'],
  })
# Out:
# time: 22 s

# %%
# Combine train set and test set
train_raw['is_train']=1
test_raw['is_train'] =0
df_combine = pd.concat([train_raw, test_raw], axis=0, ignore_index=True)

df_combine = df_combine.drop(columns=['label'])

y_combine = df_combine['is_train']
X_combine = df_combine.drop(columns=['is_train'])
# Out:
# time: 371 ms

# %%
df_combine.shape
# Out:
# (50000, 343)
# time: 5.46 ms

# %%
from lightgbm import LGBMClassifier, plot_importance
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import roc_auc_score

# kf = KFold(n_splits=6, shuffle=True)
kf = StratifiedKFold(n_splits=5, shuffle=True)
lgm = LGBMClassifier(learning_rate=0.1,num_leaves=20,n_estimators=15,ranstdom_state=42)
# Out:
# time: 232 ms

# %%
kfold_sample = []

df = pd.DataFrame()
for i in range(len(kfold)):
  print(f'{i+1}/{len(kfold)}')
  X_train, X_test = kfold[i]['X_train'], kfold[i]['X_dev']
  y_train, y_dev = kfold[i]['y_train'], kfold[i]['y_dev']

  X_train['is_train'] = 1
  X_test['is_train'] = 0
  df_combine = pd.concat([X_train, X_test], axis=0, ignore_index=True)

  X = df_combine.drop(columns=['is_train'])
  y = df_combine['is_train']

  preds = np.zeros(y.shape)  
  for trn_idx, tst_idx in kf.split(X,y):
    X_train_fold, X_test_fold = X.iloc[trn_idx, :], X.iloc[tst_idx, :]
    y_train_fold, y_test_fold = y[trn_idx], y[tst_idx]

    lgm.fit(X_train_fold, y_train_fold)
    test_probs = lgm.predict_proba(X_test_fold)[:, 1]
    print(f'ROC AUC score: {roc_auc_score(y_test_fold, test_probs)}')
  
    preds[tst_idx] = test_probs

  df[f'kfold_{i+1}'] = preds
  train_index = X_train.index.to_numpy()
  threshold = df.iloc[train_index][f'kfold_{i+1}'].quantile(0.25)
  train_sample = X_train.iloc[df.iloc[train_index][df.iloc[train_index][f'kfold_{i+1}'] >= threshold].index.to_numpy()]
  train_sample.reset_index(drop=True, inplace=True)
  y_train_sample = y_train[df.iloc[train_index][df.iloc[train_index][f'kfold_{i+1}'] >= threshold].index.to_numpy()]
  y_train_sample.reset_index(drop=True, inplace=True)

  kfold_sample.append({
      'X_train': train_sample,
      'X_dev': X_test,
      'y_train': y_train_sample,
      'y_dev': y_dev
  })
# Out:
# 1/5
# ROC AUC score: 0.8499459201388888
# ROC AUC score: 0.8535146701388888
# ROC AUC score: 0.8479339409722223
# ROC AUC score: 0.8356970486111112
# ROC AUC score: 0.8523239583333334
# 2/5
# ROC AUC score: 0.8517963541666667
# ROC AUC score: 0.8592189236111111
# ROC AUC score: 0.8418368055555555
# ROC AUC score: 0.8534060763888889
# ROC AUC score: 0.8481643229166668
# 3/5
# ROC AUC score: 0.8411171875
# ROC AUC score: 0.8435228298611112
# ROC AUC score: 0.8455200520833334
# ROC AUC score: 0.8503364583333334
# ROC AUC score: 0.8482307291666666
# 4/5
# ROC AUC score: 0.8530813368055555
# ROC AUC score: 0.8474519965277778
# ROC AUC score: 0.8455531250000001
# ROC AUC score: 0.8502588541666667
# ROC AUC score: 0.8511284722222223
# 5/5
# ROC AUC score: 0.8629205729166667
# ROC AUC score: 0.8661565104166666
# ROC AUC score: 0.8535571180555555
# ROC AUC score: 0.8566743055555556
# ROC AUC score: 0.8601327256944444
# time: 27.6 s

# %%
a = lgm.fit(X_combine, y_combine)

plot_importance(a)
# Out:
# time: 3.7 s

# %%
import copy
features_imp = pd.DataFrame(lgm.feature_importances_, columns=['feature_important'])
features_imp = pd.concat([pd.DataFrame(X.columns, columns=['feature']), features_imp], axis=1)
features_imp.sort_values(by=['feature_important'], inplace=True, ascending=False)
features_imp.reset_index(drop=True, inplace=True)
dropped_cols = features_imp[features_imp['feature_important'] >= 10]['feature'].values
print(dropped_cols)
kfold_cp = copy.deepcopy(kfold)
kfold_sample_cp = copy.deepcopy(kfold_sample)

for i in range(len(kfold_cp)):
  dropped_fold_cols = set(kfold_cp[i]['X_train'].columns).intersection(dropped_cols)
  kfold_cp[i]['X_train'].drop(columns=dropped_fold_cols, inplace=True)
  kfold_cp[i]['X_dev'].drop(columns=dropped_fold_cols, inplace=True)
  kfold_sample_cp[i]['X_train'].drop(columns=dropped_fold_cols, inplace=True)
  kfold_sample_cp[i]['X_dev'].drop(columns=dropped_fold_cols, inplace=True)
# Out:
# ['FIELD_12' 'FIELD_34.1' 'FIELD_3' 'FIELD_53' 'incomplete' 'FIELD_11'
#  'FIELD_51' 'FIELD_42_freq' 'maCv_ismiss' 'FIELD_45_woe' 'FIELD_45'
#  'FIELD_22']
# time: 356 ms

# %%
from scipy import interp
import matplotlib.pyplot as plt
from sklearn.metrics import auc, plot_roc_curve

def cross_validate_auc(model, kfold, features=None, **clf_params):
  train_tprs = []
  train_aucs = []
  train_mean_fpr = np.linspace(0, 1, 100)
  dev_tprs = []
  dev_aucs = []
  dev_mean_fpr = np.linspace(0, 1, 100)

  fig, ax = plt.subplots()
  fig.set_size_inches((16,10))
  for i in range(0, len(kfold)):
    print("{}/{}".format(i+1, len(kfold)))
    kf = kfold[i]
    X_train_kf, y_train_kf = kf["X_train"].copy(), kf["y_train"].copy()
    X_dev_kf, y_dev_kf = kf["X_dev"].copy(), kf["y_dev"].copy()
    if features is not None:
      X_train_kf = X_train_kf[features]
      X_dev_kf = X_dev_kf[features]
    

    model.fit(X_train_kf, y_train_kf, **clf_params)
    # plot train
    train_display = plot_roc_curve(model, X_train_kf, y_train_kf,
                         name='Train ROC fold {}'.format(i),
                         alpha=0.6, lw=1, ax=ax)
    train_interp_tpr = interp(train_mean_fpr, train_display.fpr, train_display.tpr)
    train_interp_tpr[0] = 0.0
    train_tprs.append(train_interp_tpr)
    train_aucs.append(train_display.roc_auc)
    # plot dev
    dev_display = plot_roc_curve(model, X_dev_kf, y_dev_kf,
                         name='Dev ROC fold {}'.format(i),
                         alpha=0.6, lw=1, ax=ax)
    dev_interp_tpr = interp(dev_mean_fpr, dev_display.fpr, dev_display.tpr)
    dev_interp_tpr[0] = 0.0
    dev_tprs.append(dev_interp_tpr)
    dev_aucs.append(dev_display.roc_auc)
  
  # plot mean train
  train_mean_tpr = np.mean(train_tprs, axis=0)
  train_mean_tpr[-1] = 1.0
  train_mean_auc = auc(train_mean_fpr, train_mean_tpr)
  train_std_auc = np.std(train_aucs)
  ax.plot(train_mean_fpr, train_mean_tpr, color='r',
        label=r'Train Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (train_mean_auc, train_std_auc),
        lw=2, alpha=1)
  # plot mean dev
  dev_mean_tpr = np.mean(dev_tprs, axis=0)
  dev_mean_tpr[-1] = 1.0
  dev_mean_auc = auc(dev_mean_fpr, dev_mean_tpr)
  dev_std_auc = np.std(dev_aucs)
  ax.plot(dev_mean_fpr, dev_mean_tpr, color='b',
        label=r'Dev Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (dev_mean_auc, dev_std_auc),
        lw=2, alpha=1)
  
  ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="Receiver operating characteristic example")
  ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))
  plt.show()

from sklearn.model_selection import KFold

def GetKFold(X, y, n_splits, random_state=None):
  splits = []
  kf = KFold(n_splits=n_splits, random_state=random_state, shuffle=True)
  for train_index, dev_index in kf.split(X):
    if isinstance(X, pd.DataFrame):
      X_train, X_dev, y_train, y_dev = X.iloc[train_index], X.iloc[dev_index], y[train_index], y[dev_index]
    elif isinstance(X, np.ndarray):
      X_train, X_dev, y_train, y_dev = X[train_index], X[dev_index], y[train_index], y[dev_index]
    splits.append({
        "X_train": X_train,
        "X_dev": X_dev,
        "y_train": y_train,
        "y_dev": y_dev,
    })
    X_train.reset_index(inplace=True, drop=True)
    y_train.reset_index(inplace=True, drop=True)
    X_dev.reset_index(inplace=True, drop=True)
    y_dev.reset_index(inplace=True, drop=True)

  return splits
# Out:
# time: 84.7 ms

# %%
from sklearn.ensemble import AdaBoostClassifier

# lgm = LGBMClassifier(learning_rate=0.1,num_leaves=3,n_estimators=30,ranstdom_state=42)
ada = AdaBoostClassifier(n_estimators=200, learning_rate=0.12)

cross_validate_auc(ada, kfold_cp)
# Out:
# 1/5
# 2/5
# 3/5
# 4/5
# 5/5
# time: 1min 49s

# %%
from sklearn.ensemble import AdaBoostClassifier

lgm = LGBMClassifier(learning_rate=0.05,num_leaves=15,n_estimators=10,ranstdom_state=42)

cross_validate_auc(lgm, kfold_sample_cp)
# Out:
# 1/5
# 2/5
# 3/5
# 4/5
# 5/5
# time: 3.95 s

# %%
for i in range(len(kfold_sample)):
  print(kfold_sample[i]['X_train'].shape)
  print(kfold_sample[i]['X_dev'].shape)
# Out:
# (18002, 246)
# (6000, 246)
# (18217, 248)
# (6000, 248)
# (18100, 251)
# (6000, 251)
# (18023, 239)
# (6000, 239)
# (18032, 247)
# (6000, 247)
# time: 3.56 ms
